# %% [markdown]
# # 2294
# - n가지의 동전
# - 해당 가치의 합이 k가 되도록하는 동전의 최소개수 구하기
#
# ## 입력
# n, k
#
# ## 출력
# - 사용한 동전의 최소 개수 출력

# %%
n, k = map(int, input().split())
coin = []
for _ in range(n):
    num = int(input())
    coin.append(num)

# print(coin)
# Out:
# [1, 5, 12]

# %%
# dp 정의를 어떻게 해야..
    # dp[x] = x원을 만들기 위해 필요한 최소 동전 개수
# 구하고자 하는 것 dp[k]

dp = [0] * (n+1)
